# %%
import pandas as pd

# %%
df1=pd.read_excel(r'C:\Users\ankur\AgentPerformance.xlsx')
# Out:
# C:\Users\ankur\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df1
# Out:
#      Agent Performance Report  Unnamed: 1          Unnamed: 2   Unnamed: 3  \
# 0                       SL No        Date          Agent Name  Total Chats
# 1                           1  2022-07-30        Prerna Singh           11
# 2                           2  2022-07-30       Nandani Gupta           11
# 3                           3  2022-07-30          Ameya Jain           14
# 4                           4  2022-07-30       Mahesh Sarade           14
# ...                       ...         ...                 ...          ...
# 2156                     2156  2022-07-01   Sowmiya Sivakumar            0
# 2157                     2157  2022-07-01             Nitin M            0
# 2158                     2158  2022-07-01              Vivek             0
# 2159                     2159  2022-07-01       Ayushi Mishra            0
# 2160                     2160  2022-07-01  Chaitra K Hiremath            0
#
# ...

# %%
df_AgentPerformance=pd.read_csv('AgentPerformance.csv')

# %%
df_AgentPerformance
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df2=pd.read_excel(r'C:\Users\ankur\Agent_Login_Report.xls')

# %%
df2
# Out:
#      Agent Login Report          Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0                   NaN                 NaN        NaN          NaN
# 1                 SL No               Agent       Date   Login Time
# 2                     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 3                     2      Khushboo Priya  30-Jul-22  03:06:59 PM
# 4                     3       Nandani Gupta  30-Jul-22  03:04:24 PM
# ...                 ...                 ...        ...          ...
# 997                 996        Manjunatha A  20-Jul-22  09:03:51 AM
# 998                 997            Bharath   20-Jul-22  09:00:49 AM
# 999                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1000                999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1001               1000              Tarun   01-Jul-22  01:52:47 AM
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1     Logout Time   Duration
# 2     05:39:39 PM   02:04:10
# 3     03:07:16 PM   00:00:17
# ...

# %%
df2.to_csv('Agent_Login_Report.csv',header=False,index=False)

# %%
df_Agent_Login_Report=pd.read_csv('Agent_Login_Report.csv')

# %%
df_Agent_Login_Report.to_csv('Agent_Login_Report.csv',header=False,index=False)

# %%
df_Agent_Login_Report=pd.read_csv('Agent_Login_Report.csv')

# %%
df_Agent_Login_Report
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df_AgentPerformance
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df_AgentPerformance.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %% [markdown]
# #### task 1:avg rating on weekly rating for every agent keep this in mind that they take 2 days of leave

# %%
df_AgentPerformance.groupby('Agent Name')['Average Rating'].sum()/4.4
# Out:
# Agent Name
# Abhishek          0.000000
# Aditya            0.000000
# Aditya Shinde    12.275000
# Aditya_iot       15.990909
# Amersh            0.000000
#                    ...
# Uday Mishra       0.000000
# Vasanth P         0.000000
# Vivek             3.413636
# Wasim            16.363636
# Zeeshan          15.593182
# Name: Average Rating, Length: 70, dtype: float64

# %% [markdown]
# #### task 2:total working days for each agent

# %%
df_Agent_Login_Report
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#       Duration                  WH  hrs  Min  Sec  Total_hrs
# 0     02:04:10 2022-07-30 02:04:10    2    4   10        NaN
# ...

# %%
df=df_Agent_Login_Report.groupby('Agent')

# %%
df

# %% [markdown]
# #### task 3:total query taken

# %%
df_AgentPerformance.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# #### task 4:total feedback received

# %%
df_AgentPerformance.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %% [markdown]
# #### task 5:agent name who have avg rating between 3.5 to 4.0

# %%
df_AgentPerformance.groupby('Agent Name')['Average Rating'].sum()/22
# Out:
# Agent Name
# Abhishek         0.000000
# Aditya           0.000000
# Aditya Shinde    2.455000
# Aditya_iot       3.198182
# Amersh           0.000000
#                    ...
# Uday Mishra      0.000000
# Vasanth P        0.000000
# Vivek            0.682727
# Wasim            3.272727
# Zeeshan          3.118636
# Name: Average Rating, Length: 70, dtype: float64

# %% [markdown]
# #### task 6:agent name who have rating less than 3.5

# %%
df_AgentPerformance[df_AgentPerformance['Average Rating']<=3.4]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1471, dtype: object

# %% [markdown]
# ##### task 7:agent name who have rating more than 4.5

# %%
df_AgentPerformance[df_AgentPerformance['Average Rating']>4.5]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %% [markdown]
# #### task 8:how many feedback agents have received more than 4.5 average

# %%
((df_AgentPerformance.groupby('Agent Name')['Total Feedback'].mean())>4.5).count()
# Out:
# 70

# %% [markdown]
# ##### tsak 9: average weekly response time for each agents

# %%
df_AgentPerformance
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df_AgentPerformance.dtypes
# Out:
# SL No                               int64
# Date                               object
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# Avg_Res_Time               datetime64[ns]
# Hrs                                 int64
# Min                                 int64
# Sec                                 int64
# dtype: object

# %%
df_AgentPerformance['Avg_Res_Time']=pd.to_datetime(df_AgentPerformance['Average Response Time'])

# %%
df_AgentPerformance['WH'] = (pd.to_datetime(df_AgentPerformance.Date) + pd.to_timedelta(df_AgentPerformance.Average Response Time))
# Out:
#   Input In [235]
#     df_AgentPerformance['WH'] = (pd.to_datetime(df_AgentPerformance.Date) + pd.to_timedelta(df_AgentPerformance.Average Response Time))
#                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
df_AgentPerformance['Hrs'] = df_AgentPerformance['Avg_Res_Time'].dt.hour

# %%
df_AgentPerformance['Min'] = df_AgentPerformance['Avg_Res_Time'].dt.hour

# %%
df_AgentPerformance['Sec'] = df_AgentPerformance['Avg_Res_Time'].dt.hour

# %%
((df_AgentPerformance.groupby('Agent Name')['Sec'].sum())+(df_AgentPerformance.groupby('Agent Name')['Min'].sum()*60)+(df_AgentPerformance.groupby('Agent Name')['Hrs'].sum()*3600))
# Out:
# Agent Name
# Abhishek         0
# Aditya           0
# Aditya Shinde    0
# Aditya_iot       0
# Amersh           0
#                 ..
# Uday Mishra      0
# Vasanth P        0
# Vivek            0
# Wasim            0
# Zeeshan          0
# Length: 70, dtype: int64

# %%
df_AgentPerformance.groupby('Agent Name')['Sec'].sum()
# Out:
# Agent Name
# Abhishek         0
# Aditya           0
# Aditya Shinde    0
# Aditya_iot       0
# Amersh           0
#                 ..
# Uday Mishra      0
# Vasanth P        0
# Vivek            0
# Wasim            0
# Zeeshan          0
# Name: Sec, Length: 70, dtype: int64

# %%
df_Agent_Login_Report['WH'] = (pd.to_datetime(df_Agent_Login_Report.Date) + pd.to_timedelta(df_Agent_Login_Report.Duration)

# %%
df_AgentPerformance['R_H'] =df_AgentPerformance['Average Response Time'].dt.hour

# %% [markdown]
# ###### task 10:list of all agents name

# %%
df_AgentPerformance.groupby('Agent Name')
# Out:
#                SL No  Date  Total Chats  Average Response Time  \
# Agent Name
# Abhishek          30    30           30                     30
# Aditya            30    30           30                     30
# Aditya Shinde     30    30           30                     30
# Aditya_iot        30    30           30                     30
# Amersh            30    30           30                     30
# ...              ...   ...          ...                    ...
# Uday Mishra       30    30           30                     30
# Vasanth P         30    30           30                     30
# Vivek             30    30           30                     30
# Wasim             30    30           30                     30
# Zeeshan           30    30           30                     30
#
#                Average Resolution Time  Average Rating  Total Feedback
# Agent Name
# Abhishek                            30              30              30
# ...

# %% [markdown]
# ##### task 11:percentage of chat on that they have received the feedback

# %%
((df_AgentPerformance.groupby('Agent Name')['Total Feedback'].sum())/(df_AgentPerformance.groupby('Agent Name')['Total Chats'].sum()))*100
# Out:
# Agent Name
# Abhishek               NaN
# Aditya                 NaN
# Aditya Shinde    55.234657
# Aditya_iot       56.709957
# Amersh                 NaN
#                    ...
# Uday Mishra            NaN
# Vasanth P              NaN
# Vivek            45.454545
# Wasim            65.588915
# Zeeshan          61.808118
# Length: 70, dtype: float64

# %% [markdown]
# ##### task 12:total contribution hour for each and every agent weekly basis

# %%
df_Agent_Login_Report
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df_Agent_Login_Report.dtypes
# Out:
# SL No                   int64
# Agent                  object
# Date                   object
# Login Time             object
# Logout Time            object
# Duration               object
# WH             datetime64[ns]
# hrs                     int64
# Min                     int64
# Sec                     int64
# Total_hrs             float64
# dtype: object

# %%
df_Agent_Login_Report.drop('converted_Duration',axis=1,inplace=True)

# %%
df_Agent_Login_Report['WH'] = (pd.to_datetime(df_Agent_Login_Report.Date) + pd.to_timedelta(df_Agent_Login_Report.Duration))

# %%
df_Agent_Login_Report
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#       Duration                  WH  hrs  Min  Sec  Total_hrs
# 0     02:04:10 2022-07-30 02:04:10    2    4   10        NaN
# ...

# %%
df_Agent_Login_Report['WH']
# Out:
# 0     2022-07-30 02:04:10
# 1     2022-07-30 00:00:17
# 2     2022-07-30 02:26:42
# 3     2022-07-30 00:45:06
# 4     2022-07-30 01:08:36
#               ...
# 995   2022-07-20 05:58:37
# 996   2022-07-20 06:00:43
# 997   2022-07-20 05:27:34
# 998   2022-07-20 05:16:38
# 999   2022-07-22 10:08:20
# Name: WH, Length: 1000, dtype: datetime64[ns]

# %%
df_Agent_Login_Report['hrs'] = df_Agent_Login_Report['WH'].dt.hour

# %%
df_Agent_Login_Report['Min'] = df_Agent_Login_Report['WH'].dt.minute

# %%
df_Agent_Login_Report['Sec'] = df_Agent_Login_Report['WH'].dt.second

# %%
df_Agent_Login_Report
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#       Duration                  WH  hrs  Min  Sec
# 0     02:04:10 2022-07-30 02:04:10    2    4   10
# ...

# %%
((df_Agent_Login_Report.groupby('Agent')['Sec'].sum()/3600)+(df_Agent_Login_Report.groupby('Agent')['Min'].sum()/60)+(df_Agent_Login_Report.groupby('Agent')['hrs'].sum()))/4.4
# Out:
# Agent
# Aditya Shinde              0.008207
# Aditya_iot                 3.575253
# Amersh                     0.696338
# Ameya Jain                 9.562626
# Ankitjha                   0.515215
# Anurag Tiwari              0.631566
# Aravind                    5.522538
# Ayushi Mishra              8.664015
# Bharath                   10.926515
# Boktiar Ahmed Bappy        9.151957
# Chaitra K Hiremath         7.801263
# Deepranjan Gupta          24.153472
# Dibyanshu                 11.953598
# Harikrishnan Shaji        12.207891
# Hrisikesh Neogi           13.083775
# Hyder Abbas                0.088194
# Ineuron Intelligence       0.329230
# Ishawant Kumar            11.767929
# Jawala Prakash            10.545960
# Jaydeep Dixit              8.145581
# Khushboo Priya             9.899684
# Madhulika G               10.468245
# Mahesh Sarade              9.754987
# Maitry                     7.032955
# Manjunatha A               9.380619
# Mithun S                  10.266730
# ...

# %% [markdown]
# ###### task 13:total percentage of active hour for a month

# %%
(((df_Agent_Login_Report.groupby('Agent')['Sec'].sum()/3600)+(df_Agent_Login_Report.groupby('Agent')['Min'].sum()/60)+(df_Agent_Login_Report.groupby('Agent')['hrs'].sum()))/176)*100
# Out:
# Agent
# Aditya Shinde              0.020518
# Aditya_iot                 8.938131
# Amersh                     1.740846
# Ameya Jain                23.906566
# Ankitjha                   1.288037
# Anurag Tiwari              1.578914
# Aravind                   13.806345
# Ayushi Mishra             21.660038
# Bharath                   27.316288
# Boktiar Ahmed Bappy       22.879893
# Chaitra K Hiremath        19.503157
# Deepranjan Gupta          60.383681
# Dibyanshu                 29.883996
# Harikrishnan Shaji        30.519729
# Hrisikesh Neogi           32.709438
# Hyder Abbas                0.220486
# Ineuron Intelligence       0.823074
# Ishawant Kumar            29.419823
# Jawala Prakash            26.364899
# Jaydeep Dixit             20.363952
# Khushboo Priya            24.749211
# Madhulika G               26.170612
# Mahesh Sarade             24.387468
# Maitry                    17.582386
# Manjunatha A              23.451547
# Mithun S                  25.666824
# ...
