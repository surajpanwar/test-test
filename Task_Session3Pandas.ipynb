# %% [markdown]
# # TASK 1: FitBit

# %%
import pandas as pd

# %%
df_fitbit=pd.read_csv('C:\\Users\\ADMIN\\Downloads\\FitBit data.csv')

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit.dropna(axis=1,inplace=True)

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit.to_json("Fitbit.json")

# %%
def myconnection(mydbname):
    '''Creating Database connection Here'''
    try:
        mydb=connection.connect(host='localhost',user='suraj',password='ThisisMyPassword',database=mydbname,use_pure=True,auth_plugin='mysql_native_password')
        return mydbname
    except Exception as e:
        print(str(e))

# %%
#read data from mysql

import mysql.connector as connection
mydb = connection.connect(host="localhost",user="suraj", passwd="ThisisMyPassword",database="Pandas_Session3",use_pure=True,auth_plugin='mysql_native_password')
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#read data from mongodb
# create connection
import pymongo
import pandas as pd
import json
client = pymongo.MongoClient("mongodb+srv://suraj:suraj123@cluster0.f8ooe.mongodb.net/?retryWrites=true&w=majority")
db = client.test
df = pd.read_csv("FitBit data.csv")

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')

# %%
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.110000134,
#   'TrackerDistance': 7.110000134,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.569999933,
#   'ModeratelyActiveDistance': 0.460000008,
#   'LightActiveDistance': 4.070000172,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.55000019,
#   'TrackerDistance': 11.55000019,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.920000076,
#   'ModeratelyActiveDistance': 0.730000019,
#   'LightActiveDistance': 3.910000086,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
#   'SedentaryMinutes': 588,
#   'Calories': 2154},
# ...

# %%
db = client["FitBitdata"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.f8ooe.mongodb.net:27017', 'cluster0-shard-00-02.f8ooe.mongodb.net:27017', 'cluster0-shard-00-01.f8ooe.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sft8sa-shard-0', tls=True), 'FitBitdata')

# %%
db.FitBit.insert_many(data)

# %%
query="select * from fitbittable WHERE Id>10000"
df_ex=pd.read_sql_query(query,engine)

# %%
df_ex
# Out:
#               Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     1503960366    3/25/2016       11004       7.110000         7.110000
# 1     1503960366    3/26/2016       17609      11.550000        11.550000
# 2     1503960366    3/27/2016       12736       8.530000         8.530000
# 3     1503960366    3/28/2016       13231       8.930000         8.930000
# 4     1503960366    3/29/2016       12041       7.850000         7.850000
# ...          ...          ...         ...            ...              ...
# 3651  8877689391   04-08-2016       23014      20.389999        20.389999
# 3652  8877689391   04-09-2016       16470       8.070000         8.070000
# 3653  8877689391   04-10-2016       28497      27.530001        27.530001
# 3654  8877689391   04-11-2016       10622       8.060000         8.060000
# 3655  8877689391   04-12-2016        2350       1.780000         1.780000
#
#       LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
query="select * from fitbittable WHERE Id>1503960366"
df_ex=pd.read_sql_query(query,engine)
df_ex
# Out:
#               Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     1624580081    3/25/2016        1810       1.180000         1.180000
# 1     1624580081    3/26/2016         815       0.530000         0.530000
# 2     1624580081    3/27/2016        1985       1.290000         1.290000
# 3     1624580081    3/28/2016        1905       1.240000         1.240000
# 4     1624580081    3/29/2016        1552       1.010000         1.010000
# ...          ...          ...         ...            ...              ...
# 3499  8877689391   04-08-2016       23014      20.389999        20.389999
# 3500  8877689391   04-09-2016       16470       8.070000         8.070000
# 3501  8877689391   04-10-2016       28497      27.530001        27.530001
# 3502  8877689391   04-11-2016       10622       8.060000         8.060000
# 3503  8877689391   04-12-2016        2350       1.780000         1.780000
#
#       LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [raw]
# 2. while creating a table in mysql dont use manual approach to create it, always use automation to create a table in mysql

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')
df_fitbit.to_sql(con=engine,name='fitbittable',if_exists="append",index=False)
# Out:
# 457

# %% [raw]
# 3. convert all the dates available in dataset to timestamp format in pandas and in sql convert it in date format

# %%
df_fitbit.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df_fitbit['ActivityDate']=pd.to_datetime(df_fitbit['ActivityDate'])

# %%
df_fitbit.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
## Converting Date in SQL

# %% [raw]
# 4. find out this data that how many unique id we have

# %%
df_fitbit.head(2)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154

# %%
df_fitbit['Id'].unique
# Out:
# <bound method Series.unique of 0      1503960366
# 1      1503960366
# 2      1503960366
# 3      1503960366
# 4      1503960366
#           ...
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# 456    8877689391
# Name: Id, Length: 457, dtype: int64>

# %%
IDs=list(pd.unique(df_fitbit['Id']))

# %%
len(IDs)
# Out:
# 35

# %% [raw]
# 5. Which id is one of the active id that you have in whole dataset

# %%
df_fitbit.groupby('Id')['TotalDistance'].mean().idxmax()
# Out:
# 8877689391

# %% [raw]
# 6.How many of them have not logged there activity find out in terms of number of ids

# %%
df_fitbit.groupby('Id')['LoggedActivitiesDistance'].count()<1
# Out:
# Id
# 1503960366    False
# 1624580081    False
# 1644430081    False
# 1844505072    False
# 1927972279    False
# 2022484408    False
# 2026352035    False
# 2320127002    False
# 2347167796    False
# 2873212765    False
# 2891001357    False
# 3372868164    False
# 3977333714    False
# 4020332650    False
# 4057192912    False
# 4319703577    False
# 4388161847    False
# 4445114986    False
# 4558609924    False
# 4702921684    False
# 5553957443    False
# 5577150313    False
# 6117666160    False
# 6290855005    False
# 6391747486    False
# 6775888955    False
# 6962181067    False
# 7007744171    False
# 7086361926    False
# 8053475328    False
# 8253242879    False
# 8378563200    False
# 8583815059    False
# 8792009665    False
# 8877689391    False
# Name: LoggedActivitiesDistance, dtype: bool

# %%
df=df_fitbit.groupby('Id')['LoggedActivitiesDistance'].sum()<1

# %%
df
# Out:
# Id
# 1503960366     True
# 1624580081     True
# 1644430081     True
# 1844505072     True
# 1927972279     True
# 2022484408     True
# 2026352035     True
# 2320127002     True
# 2347167796     True
# 2873212765     True
# 2891001357    False
# 3372868164     True
# 3977333714     True
# 4020332650     True
# 4057192912     True
# 4319703577     True
# 4388161847     True
# 4445114986     True
# 4558609924     True
# 4702921684     True
# 5553957443     True
# 5577150313     True
# 6117666160     True
# 6290855005     True
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171    False
# 7086361926     True
# 8053475328     True
# 8253242879     True
# 8378563200    False
# 8583815059     True
# 8792009665     True
# 8877689391     True
# Name: LoggedActivitiesDistance, dtype: bool

# %%
df_fitbit.groupby('Id')['LoggedActivitiesDistance'].sum().apply(lambda x:x).value_counts()
# Out:
# 0.000000     29
# 9.656064      1
# 0.055843      1
# 8.754830      1
# 14.052416     1
# 34.351326     1
# 15.127832     1
# Name: LoggedActivitiesDistance, dtype: int64

# %% [raw]
# 7. find out who is the laziest person id that we have in dataset

# %%
df_fitbit.groupby('Id')['TotalDistance'].mean().idxmin()
# Out:
# 4388161847

# %%
df_fitbit.groupby('Id')['VeryActiveMinutes'].sum().idxmin()
# Out:
# 1927972279

# %%
df_fitbit.groupby('Id')['TotalDistance'].sum().idxmin()
# Out:
# 4388161847

# %%
df_fitbit.groupby('Id')['LightlyActiveMinutes'].mean().idxmin()
# Out:
# 4388161847

# %% [raw]
# Laziest Person: 4388161847

# %% [raw]
# 8. explore over an internet that much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
#2,200–3,000--Avg male
#1,600–2,200

#2,200--Avg Person

df_fitbit.groupby('Id')['Calories'].mean().apply(lambda x:x>2200).value_counts()
# Out:
# False    22
# True     13
# Name: Calories, dtype: int64

# %% [raw]
# 13 Fit and 22 Unfit

# %% [raw]
# 9. how many person are not a regular person with respect to activity try to find out those

# %%
df_fitbit[df_fitbit['TotalSteps']==0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51   1844505072   2016-04-04           0            0.0              0.0
# 52   1844505072   2016-04-05           0            0.0              0.0
# 59   1844505072   2016-04-12           0            0.0              0.0
# 96   2320127002   2016-04-01           0            0.0              0.0
# 97   2320127002   2016-04-02           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 402  8253242879   2016-04-02           0            0.0              0.0
# 403  8253242879   2016-04-03           0            0.0              0.0
# 404  8253242879   2016-04-04           0            0.0              0.0
# 405  8253242879   2016-04-05           0            0.0              0.0
# 412  8253242879   2016-04-12           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [raw]
# 10. who is the third most active person in this dataset find out those in pandas

# %%
df_fitbit.groupby('Id')['VeryActiveMinutes'].agg(['count', 'min', 'max', 'mean']).sort_values(by = ['mean'], ascending=False)
# Out:
#             count  min  max       mean
# Id
# 8053475328     11    0  165  84.818182
# 5577150313     11    8  202  81.818182
# 8877689391     12    0  128  66.833333
# 8378563200     12    0  113  55.416667
# 7007744171     12    1  104  44.666667
# 2022484408     12    0   72  40.083333
# 1503960366     19    0   89  35.842105
# 6962181067     14    9   73  35.357143
# 7086361926     12    0   76  26.250000
# 5553957443     12    0   51  23.583333
# 6775888955      9    0   56  19.888889
# 1644430081     10    0   59  14.800000
# 3977333714     12    0   35  12.166667
# 3372868164     10    0   24  11.800000
# 2347167796     15    0   51  11.800000
# 6290855005     10    0   33   7.800000
# 4319703577     12    0   15   6.583333
# 8253242879     12    0   47   5.833333
# 6391747486      9    0   46   5.111111
# 2873212765     12    0   46   5.083333
# 4445114986     15    0   28   5.066667
# 4558609924     12    0   27   4.333333
# 4020332650     32    0   31   4.062500
# ...

# %% [raw]
# 8877689391: Third Most Active

# %% [raw]
# 11.who is the 5th most laziest person avaiilable in dataset find it out

# %%
df_fitbit.groupby('Id')['SedentaryMinutes'].mean().sort_values(ascending=False)[5:6]
# Out:
# Id
# 6391747486    1261.888889
# Name: SedentaryMinutes, dtype: float64

# %% [raw]
# 12. what is a total acumulative calories burn for a person find out

# %%
df_fitbit.groupby('Id')['Calories'].agg(['sum']).sort_values(by = ['sum'], ascending=False)
# Out:
#               sum
# Id
# 4020332650  98412
# 4057192912  60913
# 4702921684  42322
# 8877689391  41414
# 8378563200  40274
# 5577150313  36303
# 1503960366  34128
# 8053475328  31825
# 4445114986  31617
# 7007744171  31525
# 2347167796  30320
# 2022484408  29704
# 6962181067  29249
# 1644430081  29164
# 1927972279  27048
# 7086361926  26124
# 1624580081  25705
# 8792009665  24884
# 6775888955  24523
# 4319703577  23931
# 4558609924  21962
# 6290855005  21656
# 5553957443  21630
# 6117666160  20993
# 2873212765  20349
# 1844505072  19391
# 8583815059  19130
# 3372868164  18603
# 2320127002  18385
# 2891001357  18187
# 8253242879  17556
# 3977333714  16777
# 2026352035  16266
# 6391747486  15868
# 4388161847  14442

# %% [markdown]
# # TASK 2: Superstore_USA

# %% [raw]
# 1. load this data in pandas , sql with a relation in sql
# 2. while loading this data you dont have to create table manually you can use any automated approach to create a table and load the data in bulk

# %%
import pandas as pd

# %%
df_o=pd.read_excel("C://Users//ADMIN//Downloads//Superstore_USA.xlsx")
df_r=pd.read_excel("C://Users//ADMIN//Downloads//Superstore_USA.xlsx",sheet_name='Returns')

# %%
df_o
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')
df_o.to_sql(con=engine,name='superstore',if_exists="append",index=False)
# Out:
# 9426

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')
df_r.to_sql(con=engine,name='returns',if_exists="append",index=False)
# Out:
# 1634

# %% [raw]
# 3. find out how many return that we have recieved and wiht a product id

# %%
orders_returns = pd.merge(df_o,df_r)

# %%
orders_returns
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
orders_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
a=pd.DataFrame(orders_returns)

# %%
a
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#3. find out how many return that we have recieved and wiht a product id

a[(a['Status']=='Returned')].count()
# Out:
# Row ID                  98
# Order Priority          98
# Discount                98
# Unit Price              98
# Shipping Cost           98
# Customer ID             98
# Customer Name           98
# Ship Mode               98
# Customer Segment        98
# Product Category        98
# Product Sub-Category    98
# Product Container       98
# Product Name            98
# Product Base Margin     96
# Region                  98
# State or Province       98
# City                    98
# Postal Code             98
# Order Date              98
# Ship Date               98
# Profit                  98
# Quantity ordered new    98
# Sales                   98
# Order ID                98
# Status                  98
# dtype: int64

# %%
#4. try to join order and return data sql and pandas

# %%
pd.merge(df_o,df_r)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
## In MYSQL

# %%
#Join in sql
# select * from superstore INNER JOIN returns ON superstore.`Order ID`=returns.`Order ID`;

# %%
# 5. try to find out how many unique consumers we have

# %%
#In SqL
##select count(distinct `Customer ID`) from superstore;  #2703

# %%
## In Pandas
Unique_Ids=list(df_o['Customer ID'].unique())

# %%
len(Unique_Ids)
# Out:
# 2703

# %%
#6. try to find out how many regions we are selling a product and who is manager for respective region

# %%
users=pd.read_excel("C://Users//ADMIN//Downloads//Superstore_USA.xlsx",sheet_name='Users')

# %%
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
m=pd.merge(a,users)

# %%
m.groupby('Manager')['Region'].unique()
# Out:
# Manager
# Chris      [Central]
# Erin          [East]
# Sam          [South]
# William       [West]
# Name: Region, dtype: object

# %%
#7. find out how many different shipment mode we have and what is a percentage usability of all the shipment mode respect to dataset

# %%
Shipment_mode = df_o['Ship Mode']

# %%
count= pd.Series(Shipment_mode).value_counts()
count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
s = pd.DataFrame(count)

# %%
s
# Out:
#                 Ship Mode
# Regular Air          7036
# Delivery Truck       1283
# Express Air          1107

# %%
total_ship_mode = s.sum()
total_ship_mode
# Out:
# Ship Mode    9426
# dtype: int64

# %%
((s[['Ship Mode']])/total_ship_mode)*100 #percentage usablity of all the shipment mode with respect to dataset
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
#8. Create a new coulmn and try to find our a diffrence between order date and shipment date
df_o["difference_date"] =  df_o['Ship Date'] - df_o['Order Date']

# %%
df_o["difference_date"]
# Out:
# 0      2 days
# 1      1 days
# 2      1 days
# 3      1 days
# 4      0 days
#         ...
# 9421   1 days
# 9422   0 days
# 9423   2 days
# 9424   3 days
# 9425   2 days
# Name: difference_date, Length: 9426, dtype: timedelta64[ns]

# %%
df_o
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#9. Based on Question number 8, find out for which order id we have shipment duration more than 10 days 
difference = df_o['difference_date']

# %%
df_o[(df_o['difference_date'].dt.components['days']>10)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %%
df_o[(df_o['difference_date'].dt.components['days']>10)]['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
#10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
all_data = pd.concat([df_o,df_r])

# %%
all_data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date',
#        'Status'],
#       dtype='object')

# %%
all_data[(all_data['difference_date'].dt.components['days']>15)]
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 643   18246.0       Critical      0.05       11.09           5.25
# 1678  20703.0  Not Specified      0.07      130.98          30.00
# 1680  20705.0  Not Specified      0.08      115.99           4.23
# 1697   2703.0  Not Specified      0.07      130.98          30.00
# 1699   2705.0  Not Specified      0.08      115.99           4.23
# 2515  18060.0            Low      0.02        2.21           1.00
# 5673  19005.0            Low      0.06       65.99           2.50
# 5859  24392.0            Low      0.05       29.89           1.99
# 5881  21257.0            Low      0.05        7.99           5.03
# 8607  26351.0         Medium      0.00        8.32           2.38
# 8609  26350.0         Medium      0.07      180.98          55.24
# 8610  26352.0         Medium      0.06        4.20           2.26
# 8973  20750.0            Low      0.06      125.99           8.08
# ...

# %%
df_o.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
#11. Group by region and find out which region is most profitable 
df_o.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True)
# Out:
#     Region  Profit
# 2    South    1954
# 3     West    2284
# 1     East    2289
# 0  Central    2899

# %%
df_o.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True).max() #West Region is most Profitable
# Out:
# Region    West
# Profit    2899
# dtype: object

# %%
df_o['Discount'].unique()
# Out:
# array([0.01, 0.03, 0.  , 0.09, 0.08, 0.02, 0.07, 0.1 , 0.05, 0.06, 0.04,
#        0.11, 0.17, 0.16, 0.25, 0.21])

# %%
#12. Try to find out overall in which country we are giving more discount 
[df_o[df_o['Discount']>0.1]['Region']] #In central region, we are giving the most discounts.
# Out:
# [5990    Central
#  5991    Central
#  6000    Central
#  8649    Central
#  8661    Central
#  Name: Region, dtype: object]

# %%
df_o.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
#13. Give me a list of unique postal code 
df_o['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
df_o[df_o["Profit"]>100].nunique()
# Out:
# Row ID                  2635
# Order Priority             5
# Discount                  12
# Unit Price               522
# Shipping Cost            403
# Customer ID             1579
# Customer Name           1579
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name             775
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1106
# Postal Code             1278
# Order Date              1084
# Ship Date               1136
# Profit                  2584
# Quantity ordered new      99
# Sales                   2619
# Order ID                2318
# difference_date           15
# dtype: int64

# %%
#14 . which customer segement is more profitable find it out . 
df_o.groupby(['Customer Segment'])['Profit'].aggregate('count') #The corporate Customer segment is more profitable than others
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#15. try to find out the 10th most loss making product catagory . 
df_o[df_o['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2291   4659   18306         Medium      0.08      175.99           4.99
# 2121   4338   20972            Low      0.01       24.95           2.99
# 3811   7800   23213            Low      0.09     6783.02          24.49
# 2381   4844   21284       Critical      0.04      880.98          44.55
# 2660   5402   24076         Medium      0.04     6783.02          24.49
# 2664   5409   22942           High      0.05     3502.14           8.73
# 3771   7725   21048  Not Specified      0.06     6783.02          24.49
# 1061   2191   21575  Not Specified      0.05     3499.99          24.49
# 1977   4068   21917           High      0.06     3502.14           8.73
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID         Customer Name       Ship Mode Customer Segment  ...  \
# 2291         1738          Dean Solomon     Regular Air        Corporate  ...
# ...

# %%
(df_o.sort_values('Profit', ascending = True)).reset_index().iloc[[9]]
# Out:
#    index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 9   4857   24251           High      0.05     3502.14           8.73
#
#    Customer ID   Customer Name       Ship Mode Customer Segment  ...  \
# 9         1796  Carlos Johnson  Delivery Truck        Corporate  ...
#
#   State or Province           City Postal Code Order Date  Ship Date  \
# 9        California  San Francisco       94110 2013-03-23 2013-03-24
#
#       Profit Quantity ordered new   Sales  Order ID difference_date
# 9 -7961.4309                    1  3360.3     90778          1 days
#
# [1 rows x 26 columns]

# %%
#16. Try to find out 10 top  product with highest margins 
df_o.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
