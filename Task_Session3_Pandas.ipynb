# %% [markdown]
# # TASK 1: FitBit

# %%
import pandas as pd

# %%
df_fitbit=pd.read_csv('C:\\Users\\ADMIN\\Downloads\\FitBit data.csv')

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
df_fitbit.dropna(axis=1,inplace=True)

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
df_fitbit.to_json("Fitbit.json")

# %%
def myconnection(mydbname):
    '''Creating Database connection Here'''
    try:
        mydb=connection.connect(host='localhost',user='suraj',password='ThisisMyPassword',database=mydbname,use_pure=True,auth_plugin='mysql_native_password')
        return mydbname
    except Exception as e:
        print(str(e))

# %%
#read data from mysql

import mysql.connector as connection
mydb = connection.connect(host="localhost",user="suraj", passwd="ThisisMyPassword",database="Pandas_Session3",use_pure=True,auth_plugin='mysql_native_password')
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
#read data from mongodb
# create connection
import pymongo

client = pymongo.MongoClient("mongodb+srv://suraj:suraj123@cluster0.f8ooe.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')

# %%
df_fitbit.to_sql(con=engine,name='FitBitTable',if_exists="append",index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1663: UserWarning: The provided table name 'FitBitTable' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# 457

# %%
query="select * from fitbittable WHERE Id>10000"
df_ex=pd.read_sql_query(query,engine)

# %%
df_ex
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 909  8877689391   04-08-2016       23014      20.389999        20.389999
# 910  8877689391   04-09-2016       16470       8.070000         8.070000
# 911  8877689391   04-10-2016       28497      27.530001        27.530001
# 912  8877689391   04-11-2016       10622       8.060000         8.060000
# 913  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 909                       0.0               11.10                      0.63
# 910                       0.0                0.00                      0.02
# 911                       0.0               21.92                      1.12
# 912                       0.0                1.47                      0.15
# 913                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 909                 8.62                     0.00                 70
# 910                 8.02                     0.00                 90
# 911                 4.46                     0.00                128
# 912                 6.37                     0.01                 18
# 913                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 909                   29                   359               982      4196
# 910                    9                   289              1052      3841
# 911                   46                   211              1055      4526
# 912                    7                   225              1190      2820
# 913                    0                    58               531       938
#
# [914 rows x 15 columns]

# %%
query="select * from fitbittable WHERE Id>1503960366"
df_ex=pd.read_sql_query(query,engine)
df_ex
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1624580081    3/25/2016        1810       1.180000         1.180000
# 1    1624580081    3/26/2016         815       0.530000         0.530000
# 2    1624580081    3/27/2016        1985       1.290000         1.290000
# 3    1624580081    3/28/2016        1905       1.240000         1.240000
# 4    1624580081    3/29/2016        1552       1.010000         1.010000
# ..          ...          ...         ...            ...              ...
# 871  8877689391   04-08-2016       23014      20.389999        20.389999
# 872  8877689391   04-09-2016       16470       8.070000         8.070000
# 873  8877689391   04-10-2016       28497      27.530001        27.530001
# 874  8877689391   04-11-2016       10622       8.060000         8.060000
# 875  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                0.00                      0.00
# 1                         0.0                0.00                      0.00
# 2                         0.0                0.00                      0.00
# 3                         0.0                0.00                      0.00
# 4                         0.0                0.00                      0.00
# ..                        ...                 ...                       ...
# 871                       0.0               11.10                      0.63
# 872                       0.0                0.00                      0.02
# 873                       0.0               21.92                      1.12
# 874                       0.0                1.47                      0.15
# 875                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   1.13                     0.01                  0
# 1                   0.53                     0.00                  0
# 2                   1.28                     0.01                  0
# 3                   1.24                     0.00                  0
# 4                   1.00                     0.00                  0
# ..                   ...                      ...                ...
# 871                 8.62                     0.00                 70
# 872                 8.02                     0.00                 90
# 873                 4.46                     0.00                128
# 874                 6.37                     0.01                 18
# 875                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                      0                   121              1319      1373
# 1                      0                    47              1393      1264
# 2                      0                   112              1328      1350
# 3                      0                    95              1345      1342
# 4                      0                    66              1374      1300
# ..                   ...                   ...               ...       ...
# 871                   29                   359               982      4196
# 872                    9                   289              1052      3841
# 873                   46                   211              1055      4526
# 874                    7                   225              1190      2820
# 875                    0                    58               531       938
#
# [876 rows x 15 columns]

# %% [raw]
# 2. while creating a table in mysql dont use manual approach to create it, always use automation to create a table in mysql

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')
df_fitbit.to_sql(con=engine,name='fitbittable',if_exists="append",index=False)
# Out:
# 457

# %% [raw]
# 3. convert all the dates available in dataset to timestamp format in pandas and in sql convert it in date format

# %%
df_fitbit.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df_fitbit['ActivityDate']=pd.to_datetime(df_fitbit['ActivityDate'])

# %%
df_fitbit.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
## Converting Date in SQL

# %% [raw]
# 4. find out this data that how many unique id we have

# %%
df_fitbit.head(2)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154

# %%
df_fitbit['Id'].unique
# Out:
# <bound method Series.unique of 0      1503960366
# 1      1503960366
# 2      1503960366
# 3      1503960366
# 4      1503960366
#           ...
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# 456    8877689391
# Name: Id, Length: 457, dtype: int64>

# %%
IDs=list(pd.unique(df_fitbit['Id']))

# %%
len(IDs)
# Out:
# 35

# %% [raw]
# 5. Which id is one of the active id that you have in whole dataset

# %%
df_fitbit.groupby('Id')['TotalDistance'].mean().idxmax()
# Out:
# 8877689391

# %% [raw]
# 6.How many of them have not logged there activity find out in terms of number of ids

# %%
df_fitbit.groupby('Id')['LoggedActivitiesDistance'].count()<1
# Out:
# Id
# 1503960366    False
# 1624580081    False
# 1644430081    False
# 1844505072    False
# 1927972279    False
# 2022484408    False
# 2026352035    False
# 2320127002    False
# 2347167796    False
# 2873212765    False
# 2891001357    False
# 3372868164    False
# 3977333714    False
# 4020332650    False
# 4057192912    False
# 4319703577    False
# 4388161847    False
# 4445114986    False
# 4558609924    False
# 4702921684    False
# 5553957443    False
# 5577150313    False
# 6117666160    False
# 6290855005    False
# 6391747486    False
# 6775888955    False
# 6962181067    False
# 7007744171    False
# 7086361926    False
# 8053475328    False
# 8253242879    False
# 8378563200    False
# 8583815059    False
# 8792009665    False
# 8877689391    False
# Name: LoggedActivitiesDistance, dtype: bool

# %%
df=df_fitbit.groupby('Id')['LoggedActivitiesDistance'].sum()<1

# %%
df
# Out:
# Id
# 1503960366     True
# 1624580081     True
# 1644430081     True
# 1844505072     True
# 1927972279     True
# 2022484408     True
# 2026352035     True
# 2320127002     True
# 2347167796     True
# 2873212765     True
# 2891001357    False
# 3372868164     True
# 3977333714     True
# 4020332650     True
# 4057192912     True
# 4319703577     True
# 4388161847     True
# 4445114986     True
# 4558609924     True
# 4702921684     True
# 5553957443     True
# 5577150313     True
# 6117666160     True
# 6290855005     True
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171    False
# 7086361926     True
# 8053475328     True
# 8253242879     True
# 8378563200    False
# 8583815059     True
# 8792009665     True
# 8877689391     True
# Name: LoggedActivitiesDistance, dtype: bool

# %%
df_fitbit.groupby('Id')['LoggedActivitiesDistance'].sum().apply(lambda x:x).value_counts()
# Out:
# 0.000000     29
# 9.656064      1
# 0.055843      1
# 8.754830      1
# 14.052416     1
# 34.351326     1
# 15.127832     1
# Name: LoggedActivitiesDistance, dtype: int64

# %% [raw]
# 7. find out who is the laziest person id that we have in dataset

# %%
df_fitbit.groupby('Id')['TotalDistance'].mean().idxmin()
# Out:
# 4388161847

# %%
df_fitbit.groupby('Id')['VeryActiveMinutes'].sum().idxmin()
# Out:
# 1927972279

# %%
df_fitbit.groupby('Id')['TotalDistance'].sum().idxmin()
# Out:
# 4388161847

# %%
df_fitbit.groupby('Id')['LightlyActiveMinutes'].mean().idxmin()
# Out:
# 4388161847

# %% [raw]
# Laziest Person: 4388161847

# %% [raw]
# 8. explore over an internet that much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
#2,200–3,000--Avg male
#1,600–2,200

#2,200--Avg Person

df_fitbit.groupby('Id')['Calories'].mean().apply(lambda x:x>2200).value_counts()
# Out:
# False    22
# True     13
# Name: Calories, dtype: int64

# %% [raw]
# 13 Fit and 22 Unfit

# %% [raw]
# 9. how many person are not a regular person with respect to activity try to find out those

# %%
df_fitbit[df_fitbit['TotalSteps']==0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
#
# 6290855005     10    0   33   7.800000
# 4319703577     12    0   15   6.583333
# 8253242879     12    0   47   5.833333
# 6391747486      9    0   46   5.111111
# 2873212765     12    0   46   5.083333
# 4445114986     15    0   28   5.066667
# 4558609924     12    0   27   4.333333
# 4020332650     32    0   31   4.062500
# 4702921684     15    0   15   2.933333
# 8792009665     12    0    9   1.500000
# 4057192912     32    0   30   1.250000
# 2320127002     12    0   10   0.916667
# 1844505072     12    0    9   0.750000
# 1624580081     19    0    7   0.736842
# 8583815059      8    0    5   0.625000
# 6117666160     10    0    3   0.500000
# 1927972279     12    0    0   0.000000
# 4388161847      8    0    0   0.000000
# 2891001357      8    0    0   0.000000
# 2026352035     12    0    0   0.000000

# %% [raw]
# 8877689391: Third Most Active

# %% [raw]
# 11.who is the 5th most laziest person avaiilable in dataset find it out

# %%
df_fitbit.groupby('Id')['SedentaryMinutes'].mean().sort_values(ascending=False)[5:6]
# Out:
# Id
# 6391747486    1261.888889
# Name: SedentaryMinutes, dtype: float64

# %% [raw]
# 12. what is a total acumulative calories burn for a person find out

# %%
df_fitbit.groupby('Id')['Calories'].agg(['sum']).sort_values(by = ['sum'], ascending=False)
# Out:
#               sum
# Id
# 4020332650  98412
# 4057192912  60913
# 4702921684  42322
# 8877689391  41414
# 8378563200  40274
# 5577150313  36303
# 1503960366  34128
# 8053475328  31825
# 4445114986  31617
# 7007744171  31525
# 2347167796  30320
# 2022484408  29704
# 6962181067  29249
# 1644430081  29164
# 1927972279  27048
# 7086361926  26124
# 1624580081  25705
# 8792009665  24884
# 6775888955  24523
# 4319703577  23931
# 4558609924  21962
# 6290855005  21656
# 5553957443  21630
# 6117666160  20993
# 2873212765  20349
# 1844505072  19391
# 8583815059  19130
# 3372868164  18603
# 2320127002  18385
# 2891001357  18187
# 8253242879  17556
# 3977333714  16777
# 2026352035  16266
# 6391747486  15868
# 4388161847  14442

# %% [markdown]
# # TASK 2: Superstore_USA

# %% [raw]
# 1. load this data in pandas , sql with a relation in sql
# 2. while loading this data you dont have to create table manually you can use any automated approach to create a table and load the data in bulk

# %%
import pandas as pd

# %%
df_s=pd.read_excel("C://Users//ADMIN//Downloads//Superstore_USA.xlsx")
df_r=pd.read_excel("C://Users//ADMIN//Downloads//Superstore_USA.xlsx",sheet_name='Returns')

# %%
df_r
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://suraj:ThisisMyPassword@localhost:3306/Pandas_Session3')
df_s.to_sql(con=engine,name='superstore',if_exists="append",index=False)
# Out:
# 9426

# %% [raw]
# 3. find out how many return that we have recieved and wiht a product id
